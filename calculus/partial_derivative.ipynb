# %%
from sympy import *
from sympy.plotting import plot3d

x,y = symbols('x y')

f = 2*x**3 + 3*y**3

dx_f = diff(f ,x)
dy_f = diff(f, y)

print(f"x에 대한 f의 편도함수 : {dx_f}")
print(f"y에 대한 f의 편도함수 : {dy_f}")

p = plot3d(f, show= False)
p.show()
# Out:
# x에 대한 f의 편도함수 : 6*x**2
# y에 대한 f의 편도함수 : 9*y**2
