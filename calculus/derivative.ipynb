# %%
from sympy import Derivative, symbols
from sympy.plotting import plot

x = symbols('x')
fx = 4*(x**4)+3*x

f_prime = Derivative(fx, x).doit()
print(f"fx의 도함수 {f_prime}")

value_in_3 = f_prime.subs({ x: 3 })
print(f"x=3에서의 기울기 : {value_in_3}")

f_prime_prime = Derivative(f_prime, x).doit()
print(f"fx의 2계도함수 {f_prime_prime}")

p = plot(fx, f_prime, f_prime_prime, legend= True, show=False)
p[0].line_color = '#FF6400'
p[1].line_color = '#00FF00'
p[2].line_color = '#0064FF'

p.show()
# Out:
# fx의 도함수 16*x**3 + 3
# x=3에서의 기울기 : 435
# fx의 2계도함수 48*x**2
